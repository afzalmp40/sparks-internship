# %% [markdown]
# # SPARKS GRIP task #3 sample superstore
# # - by **AFZAL QURESHI**
# ### **Data cleaning and univariate analysis has been carried out in this notebook.**
# ### **Head over to the link given below for viz in tableau:**
# ### https://public.tableau.com/app/profile/afzalmp40/viz/SparksGRIPtask3SuperstorebyAfzal/start

# %%
import pandas as pd
from sys import path 
path.insert(0, 'D:/python/PROJECTS/GIT/sparks-internship/')

# %% [markdown]
# ### Importing data

# %%
df=pd.read_csv('Superstore.csv')

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ### *Looks like no missing values*
#
# ### Lets have a look at the classes in the categorical features

# %%
for col in df.select_dtypes('object').columns:
    print(col + ':\n' , sorted(list( df[col].unique())) )
    print()
# Out:
# Ship Mode:
#  ['First Class', 'Same Day', 'Second Class', 'Standard Class']
#
# Segment:
#  ['Consumer', 'Corporate', 'Home Office']
#
# Country:
#  ['United States']
#
# City:
# ...

# %% [markdown]
# ### *All the data in the categorical features seems to be clean as there are no repetitive values*
# ### So lets proceed with the univariate analysis

# %% [markdown]
# # **Univariate Analysis**

# %%
####################################
'''IMPORTING FROM A CUSTOM MODULE'''
####################################
from quick_EDA import analysis_cate, analysis_quant

# %% [markdown]
# ### Analysis of categorical features

# %%
analysis_cate(df, columns=df.select_dtypes('object').columns, figsize=(30,4), dpi=150)
# Out:
# 				ANALYSIS OF: Ship Mode
#
# No. of UNIQUE values:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64
# _____________________________________________________________________________________________________________________
# 				ANALYSIS OF: Segment
#
# No. of UNIQUE values:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64
# _____________________________________________________________________________________________________________________
# 				ANALYSIS OF: Country
#
# No. of UNIQUE values:
# United States    9994
# Name: Country, dtype: int64
# _____________________________________________________________________________________________________________________
# 				ANALYSIS OF: City
#
# The feature "City" might be numerical. Please try the "analysis_quant" function.
# Incase you want to proceed anyways, set "force" parameter to True.
# ...

# %% [markdown]
# ### Key Takeaways:
# + The only country present is USA
# + **Standard** class seems to be most **popular shipping method**
# + **Consumer**(individual) seems to be the most **popular segment**
# + **Office suppies** seems to be most **frequent in Category**
# + There are a lot of classes in subcategory
# + **City and state seems to have way too many classes**

# %% [markdown]
# ### Analysis of quantative features

# %%
analysis_quant(df, columns=df.select_dtypes(exclude='object').columns, bins=100)
# Out:
# 				ANALYSIS OF: Postal Code
#
# 5 point summary for: Postal Code
#      Postal Code
# min       1040.0
# 25%      23223.0
# 50%      56430.5
# 75%      90008.0
# max      99301.0
# ---------------------------------
# OUTLIERS in Postal Code via Z score
#
# Outlier limits:
# lower limit: -40995.888061580124
# upper limit: 151376.6469168933
#
# Total outliers: 0
# ---------------------------------
# OUTLIERS in Postal Code via IQR
#
# Outlier limits:
# lower limit: -76954.5
# upper limit: 190185.5
#
# Total outliers: 0
# ---------------------------------
# ___________________________________________________________________________________________________________
# 				ANALYSIS OF: Sales
#
# 5 point summary for: Sales
#          Sales
# min      0.444
# 25%     17.280
# 50%     54.490
# 75%    209.940
# max  22638.480
# ---------------------------------
# OUTLIERS in Sales via Z score
#
# Outlier limits:
# lower limit: -1639.7837554646399
# upper limit: 2099.4997571256367
#
# ...

# %% [markdown]
# ### Key Takeaways:
# + distribution of Sales seems to be highly right skewed hence **lower sales is more prevalent**
# + "**Quantity**" seems to be a **discrete** feature with peak around 2 to 3
# + "**Discount**" seems to be **discrete** feature with value of 0 or 0.2 more prevalent
# + "**Profit**" seems to follow a **normal** distribution

# %% [markdown]
# # Now lets Proceed to Tableau for multivariate analysis
# ### Tableau public link:</br>https://public.tableau.com/app/profile/afzalmp40/viz/SparksGRIPtask3SuperstorebyAfzal/start
